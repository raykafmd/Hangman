# %%
import random
import time
print("Hello, Welcome to Hangman!")
time.sleep(4)
print("All words should have a lower case at the begining!")
print("Write one word, not a letter.")

def MAIN():
  secret_words = ["1", "2", "3", "4"]
  real_word = []
  guess = ""
  guess_count = 0
  for p in secret_words:
    real_word = random.choice(secret_words)
    if real_word == "1":
      real_word = "banana"
    if real_word == "2":
      real_word = "lemon"
    if real_word == "3":
      real_word = "plum"
    if real_word == "4":
      real_word = "apple"
  if real_word == "banana":
    while guess != real_word:
      guess = input("enter guess")
      guess_count = guess_count + 1
      if guess != real_word:
        print("You made a mistake, try again")
      if guess_count == 2:
        print("It is a fruit")
      if guess_count == 3:
        print("The colour is yellow")
      if guess_count == 4:
        print("It is a six letter word")
      if guess_count > 6:
        print("I am sorry, you ran out of turns.")
        break
    if guess == real_word:
      print("Congratulations!, you win!!")
  if real_word == "lemon":
      while guess != real_word:
        guess = input("enter guess")
        guess_count = guess_count + 1
        if guess != real_word:
          print("You made a mistake, try again")
        if guess_count == 2:
          print("It is a fruit")
        if guess_count == 3:
          print("The colour is yellow")
        if guess_count == 4:
          print("It is a five letter word")
        if guess_count > 6:
          print("I am sorry, you ran out of turns.")
          break
      if guess == real_word:
        print("Congratulations!, you win!!")
  if real_word == "plum":
      while guess != real_word:
        guess = input("enter guess")
        guess_count = guess_count + 1
        if guess != real_word:
          print("You made a mistake, try again")
        if guess_count == 2:
          print("It is a fruit")
        if guess_count == 3:
          print("The colour can be yellow")
        if guess_count == 4:
          print("It is a four letter word")
        if guess_count > 6:
          print("I am sorry, you ran out of turns.")
          break
        if guess == real_word:
          print("Congratulations!, you win!!")
  if real_word == "apple":
    while guess != real_word:
        guess = input("enter guess")
        guess_count = guess_count + 1
        if guess != real_word:
          print("You made a mistake, try again")
        if guess_count == 2:
          print("It is a fruit")
        if guess_count == 3:
          print("The colour is yellow")
        if guess_count == 4:
          print("It is a five letter word")
        if guess_count > 6:
          print("I am sorry, you ran out of turns.")
          break
        if guess == real_word:
          print("Congratulations!, you win!!")

MAIN()
# Out:
# Hello, Welcome to Hangman!
# All words should have a lower case at the begining!
# enter guessl
# You made a mistake, try again
# enter guessa
# You made a mistake, try again
# It is a fruit
# enter guessp
# You made a mistake, try again
# The colour is yellow
# enter guessb
# You made a mistake, try again
# It is a five letter word
# enter guesslemon
# You made a mistake, try again
# enter guessapple
# Congratulations!, you win!!
